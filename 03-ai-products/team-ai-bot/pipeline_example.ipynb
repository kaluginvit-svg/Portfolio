# %% [markdown]
# # Pipeline Example Reference
#
# Этот notebook оставлен в корне проекта как учебный reference для задания по уроку. Основной рабочий код проекта находится в `src/pipelines/`.
#
# Для реализации использован актуальный Haystack 2.x стиль: `Pipeline`, `OpenAIDocumentEmbedder`, `OpenAITextEmbedder`, `DocumentWriter`, `PineconeDocumentStore`, `PineconeEmbeddingRetriever`, `ChatPromptBuilder`, `OpenAIChatGenerator`.

# %%
from haystack import Pipeline, Document
from haystack.components.embedders import OpenAIDocumentEmbedder, OpenAITextEmbedder
from haystack.components.writers import DocumentWriter
from haystack_integrations.components.retrievers.pinecone import PineconeEmbeddingRetriever
from haystack_integrations.document_stores.pinecone import PineconeDocumentStore

# См. рабочую реализацию в src/pipelines/manager.py
